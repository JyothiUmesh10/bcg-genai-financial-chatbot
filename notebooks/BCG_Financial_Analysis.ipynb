# %%
import pandas as pd

# Step 1: Read the Excel file
excel_path = r"C:\Users\timon\OneDrive\Jyothi\Skills\GitHub\bcg-genai-financial-chatbot\data\raw\financial_data_raw.xlsx"

df = pd.read_excel(excel_path)

# Step 2: Save it as CSV
csv_path = r"C:\Users\timon\OneDrive\Jyothi\Skills\GitHub\bcg-genai-financial-chatbot\data\raw\financial_data_raw.csv"

df.to_csv(csv_path, index=False)

print("Excel successfully converted to CSV!")
# Out:
# Excel successfully converted to CSV!

# %%
# Load the CSV file
csv_path = r"C:\Users\timon\OneDrive\Jyothi\Skills\GitHub\bcg-genai-financial-chatbot\data\raw\financial_data_raw.csv"

df = pd.read_csv(csv_path)

df.head()
# Out:
#     Company   Year   Total Revenue   Net Income   Total Assets  \
# 0  Microsoft   2025         281724        101832        619003
# 1  Microsoft   2024         245122         88136        512163
# 2  Microsoft   2023         211915         72361        411976
# 3      Tesla   2025          94827          3794        137806
# 4      Tesla   2024          97690          7091        122070
#
#     Total Liabilities  Cash Flow from Operating Activities
# 0              275524                               136162
# 1              243686                               118548
# 2              205753                                87582
# 3               54941                                13256
# 4               48390                                13456

# %%
df.columns
# Out:
# Index(['Company ', 'Year ', 'Total Revenue', ' Net Income ', 'Total Assets',
#        ' Total Liabilities', 'Cash Flow from Operating Activities'],
#       dtype='str')

# %%
# Remove leading/trailing spaces from all column names
df.columns = df.columns.str.strip()

# Check again to confirm
df.columns
# Out:
# Index(['Company', 'Year', 'Total Revenue', 'Net Income', 'Total Assets',
#        'Total Liabilities', 'Cash Flow from Operating Activities'],
#       dtype='str')

# %%
df = df.sort_values(by=["Company", "Year"])

df
# Out:
#      Company  Year  Total Revenue  Net Income  Total Assets  \
# 8      Apple  2023         383285       96995        352583
# 7      Apple  2024         391035       93736        364980
# 6      Apple  2025         416161      112010        359241
# 2  Microsoft  2023         211915       72361        411976
# 1  Microsoft  2024         245122       88136        512163
# 0  Microsoft  2025         281724      101832        619003
# 5      Tesla  2023          96773       14997        106618
# 4      Tesla  2024          97690        7091        122070
# 3      Tesla  2025          94827        3794        137806
#
#    Total Liabilities  Cash Flow from Operating Activities
# 8             290437                               110543
# 7             308030                               118254
# 6             285508                               111482
# 2             205753                                87582
# 1             243686                               118548
# ...

# %%
# Calculate Revenue Growth (%)
df['Revenue Growth (%)'] = df.groupby('Company')['Total Revenue'].pct_change() * 100

# Calculate Net Income Growth (%)
df['Net Income Growth (%)'] = df.groupby('Company')['Net Income'].pct_change() * 100

df
# Out:
#      Company  Year  Total Revenue  Net Income  Total Assets  \
# 8      Apple  2023         383285       96995        352583
# 7      Apple  2024         391035       93736        364980
# 6      Apple  2025         416161      112010        359241
# 2  Microsoft  2023         211915       72361        411976
# 1  Microsoft  2024         245122       88136        512163
# 0  Microsoft  2025         281724      101832        619003
# 5      Tesla  2023          96773       14997        106618
# 4      Tesla  2024          97690        7091        122070
# 3      Tesla  2025          94827        3794        137806
#
#    Total Liabilities  Cash Flow from Operating Activities  Revenue Growth (%)  \
# 8             290437                               110543                 NaN
# 7             308030                               118254            2.021994
# 6             285508                               111482            6.425512
# ...

# %%
df['Asset Growth (%)'] = df.groupby('Company')['Total Assets'].pct_change() * 100
df['Liability Growth (%)'] = df.groupby('Company')['Total Liabilities'].pct_change() * 100
df['Cash Flow Growth (%)'] = df.groupby('Company')['Cash Flow from Operating Activities'].pct_change() * 100

df
# Out:
#      Company  Year  Total Revenue  Net Income  Total Assets  \
# 8      Apple  2023         383285       96995        352583
# 7      Apple  2024         391035       93736        364980
# 6      Apple  2025         416161      112010        359241
# 2  Microsoft  2023         211915       72361        411976
# 1  Microsoft  2024         245122       88136        512163
# 0  Microsoft  2025         281724      101832        619003
# 5      Tesla  2023          96773       14997        106618
# 4      Tesla  2024          97690        7091        122070
# 3      Tesla  2025          94827        3794        137806
#
#    Total Liabilities  Cash Flow from Operating Activities  Revenue Growth (%)  \
# 8             290437                               110543                 NaN
# 7             308030                               118254            2.021994
# 6             285508                               111482            6.425512
# ...

# %% [markdown]
# # Financial Trend Analysis (2023–2025)
#
# ## Apple
# - Revenue shows steady growth, with stronger acceleration in 2025.
# - Net income declined slightly in 2024 but rebounded strongly in 2025.
# - Assets and liabilities fluctuated slightly in 2025.
# - Cash flow from operations slightly decreased in 2025.
#
# ## Microsoft
# - Strong and consistent revenue growth across all years.
# - Net income shows strong upward trend.
# - Assets and liabilities increased steadily.
# - Cash flow from operations shows healthy expansion.
#
# ## Tesla
# - Revenue growth slowed and turned negative in 2025.
# - Net income declined sharply in both 2024 and 2025.
# - Assets and liabilities continued to grow.
# - Cash flow remained relatively stable but slightly declined in 2025.
#
# ## Overall Observations
# - Microsoft shows the most consistent and stable growth.
# - Apple shows moderate growth with slight volatility.
# - Tesla shows profitability challenges despite asset growth.
